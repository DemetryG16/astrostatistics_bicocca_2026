# %% [markdown]
# # The Notes structure:
# * PDF
# * CLT
# *

# %%
import numpy as np
import scipy.stats
import pylab as plt

# %% [markdown]
# # Probability Desity Function (PDF)
# ### Deals with one sample a time.
# ---

# %% [markdown]
# ### The pdf is a function that tells you the probability of having a value between a set of values:
# * **Example:** If you have the pdf f(x):
#
#      Take $x=9$. **The the probablity of having the value $x=9$ is f(9) out of this set of data.**

# %% [markdown]
# #### Follow this example to understand:
#
# **!! This example shows the Probability Mass Function (PMF). But it is the same principle for a PDF.**
#
# **If we smooth the PMF, we can approximate f(x) to be a PDF.**

# %%
# You have this data set:
data_set = [1,2,3,0.5,0.55,0.6,1,1,1,5,0,7,7,7,7,4,20,20,20,20,20,20,20,20,19,18,17]


freq = np.ones_like(data_set)*100/len(data_set) # The percentage of getting a value.

fig , (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize= (12,5))
ax1.hist(data_set, bins= 100, color = 'green')
ax1.set_ylabel("The number of each value")
ax1.set_title('Simple Histogram')
ax1.set_xlabel("x")

ax2.hist(data_set, bins= 100, weights= freq, color = 'red')
ax2.set_ylabel("Probability %")
ax2.set_title('The percentage of each')
ax2.set_xlabel("x")

# For ax3, get each value with its counts probability to find the probability function.
values, counts = np.unique(data_set, return_counts=True)
prob = counts / len(data_set) * 100

ax3.plot(values, prob, color = 'blue')
ax3.set_ylabel("Probability %")
ax3.set_xlabel("x")
ax3.set_title('PMF = f(x) ~ PDF')

ax4.plot(values, prob, color = 'blue')
ax4.hist(data_set, bins= 100, weights= freq, color = 'red')
ax4.set_ylabel("Probability %")
ax4.set_xlabel("x")
ax4.set_title('Combined')


fig.suptitle('Transfrom histogram into a function')
fig.tight_layout()
plt.show()

# %% [markdown]
# I used the data_set again in the following code to build a pdf ---->

# %%
# Extract the data histogram values:
counts, bins = np.histogram(data_set, bins=100, density=True)

y = scipy.stats.rv_histogram((counts,bins))
x = np.linspace(min(data_set),max(data_set)+1,100)

pdf = y.pdf(x) 
plt.plot(x,pdf)
plt.title('PDF instead of PMF')
plt.show()

# %% [markdown]
# # Central Limit Theorem (CLT)

# %% [markdown]
# #### For the pdf, we do it only for one sample, while:
# * CLT takes more than one sample for the same pdf.
# * The population mean is the mean of all the pdf sample means.

# %%
# Simple draw for some variables regarding an exponential
N = 100
samples = np.random.exponential(scale=1, size=N) # It chooses regarding 
mu = np.mean(samples)
sigma = np.std(samples)
print(mu,sigma)
plt.hist(samples, bins= 100)
plt.show()
# Out:
# 0.8680761847053575 0.8285977044377636

# %%
N = 100
means = []
sigmas = []
for n in range(1,10001):
 samples = np.random.exponential(scale=1, size=N) # It chooses random values 
 mu = np.mean(samples)
 sigma = np.std(samples)
 means.append(mu)
 sigmas.append(sigma)

sigma_tot = np.std(means)
print('Mean_sample vs Mean_population')
print(mu , np.mean(means))
print('sigma_population vs sigma_sample')
print(sigma/np.sqrt(N),sigma_tot)
plt.hist(means, bins= 100, density= True)
plt.show()
# Out:
# Mean_sample vs Mean_population
# 0.9922170053179186 0.9992350460788281
# sigma_population vs sigma_sample
# 0.0981778666163283 0.10021074161149071
